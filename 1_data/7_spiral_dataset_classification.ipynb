# %% [markdown]
# <h4>Deep Learning Network Train<h4>
# <h6>
# input(2)</br>
# dense(16, relu)</br>
# dense(16, relu)</br>
# dense(16, relu)</br>
# dense(16, relu)</br>
# dense(1, sigmoid)</br></h6>

# %%
import pandas as pd
import numpy as np
np.random.seed(4375689)

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop

train_data = pd.read_csv('spiral.csv').values
train_X = train_data[:,0:2]
train_y = train_data[:,2]

print('train_X.shape', train_X.shape)
print('train_y.shape', train_y.shape)

colors = ['C'+str(int(v)) for v in train_y]
import matplotlib.pyplot as plt
plt.scatter(train_X[:,0], train_X[:,1], c=colors)
plt.show()
# Out:
# train_X.shape (191, 2)
# train_y.shape (191,)

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(2,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=RMSprop(),
              metrics=['accuracy'])

print('fit')
history = model.fit(train_X, train_y, batch_size=32, epochs=100, verbose=0)

print('evaluate')
score = model.evaluate(train_X, train_y, verbose=2)

print('loss=', score[0], 'acc=', score[1])
# Out:
# fit
# evaluate
# 6/6 - 0s - loss: 0.6769 - accuracy: 0.6387 - 74ms/epoch - 12ms/step
# loss= 0.6769465804100037 acc= 0.6387434601783752
